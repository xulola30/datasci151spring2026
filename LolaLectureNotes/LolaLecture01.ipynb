# %%
These are where lectre notes will be written, describing whats happening in the code cells

# %%
#Big text

# %%
print("hello, world")
# Out:
# hello, world

# %%
print("hello, world")
# Out:
# hello, world
